# %% [markdown]
# ## Step-by-step guide to generating an interactive climate map in Folium (& Geopandas)
#
# - **With some specific boilerplate code already filled in.**

# %% [markdown]
# ---

# %% [markdown]
# - **CREDITS**:
#
#     - This tutorial was adapted by [Paul Wlodkowski](https://github.com/pawlodkowski) for the *Plotting on Maps* lesson @ Spiced Academy.
#         - The data for this particular lesson was scraped from [Berkeley Earth](http://berkeleyearth.lbl.gov/country-list/) and cleaned / pre-processed ahead of time.

# %% [markdown]
# - **Make sure you already have folium and geopandas installed**! (e.g. `pip` or `conda`), e.g.:
#
#     - `pip install folium`
#
#     - `pip install geopandas==0.8.0`

# %% [markdown]
# *Note*: this notebook was last run and tested on geopandas version 0.8.0 (released July 15, 2020). The latest version of folium should work just fine.

# %% [markdown]
# ---

# %% [markdown]
# ### STEP 1: Read in historical temperature data
# - Historical temperature data scraped for all countries from [Berkeley Earth](http://berkeleyearth.lbl.gov/country-list/)
# - According to Berkeley Earth: "Temperatures are in Celsius and reported as anomalies relative to the Jan 1951-Dec 1980 average."

# %%
DATA = 'data/all_country_temp_data_CLEAN.csv'

# %%
#Read in the data with pandas
import pandas as pd
df = pd.read_csv(DATA)

# %%
df.head()
# Out:
#        country  year  month  monthly_anomaly  monthly_uncertainty
# 0  Afghanistan  1900      1           -4.048                0.936
# 1  Afghanistan  1900      2           -2.086                1.135
# 2  Afghanistan  1900      3            1.835                0.933
# 3  Afghanistan  1900      4           -1.268                0.536
# 4  Afghanistan  1900      5            0.360                0.524

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### STEP 2: Read in the geographic data (geometric shapes of all countries in the world)
# - Hint: Use GeoPandas
#     - What is a **Shape file (.shp)?**
#         - https://en.wikipedia.org/wiki/Shapefile#Shapefile_shape_format_(.shp)
# - What is GIS?:
# https://www.esri.com/en-us/what-is-gis/overview

# %%
SHAPEFILE = 'data/ne_110m_admin_0_countries.shp'

# %%
#Read in the shapefile with geopandas
import geopandas as gpd
gdf = gpd.read_file(SHAPEFILE)

# %%
gdf
# Out:
#           featurecla  scalerank  LABELRANK                   SOVEREIGNT  \
# 0    Admin-0 country          1          6                         Fiji
# 1    Admin-0 country          1          3  United Republic of Tanzania
# 2    Admin-0 country          1          7               Western Sahara
# 3    Admin-0 country          1          2                       Canada
# 4    Admin-0 country          1          2     United States of America
# ..               ...        ...        ...                          ...
# 172  Admin-0 country          1          5           Republic of Serbia
# 173  Admin-0 country          1          6                   Montenegro
# 174  Admin-0 country          1          6                       Kosovo
# 175  Admin-0 country          1          5          Trinidad and Tobago
# 176  Admin-0 country          1          3                  South Sudan
#
#     SOV_A3  ADM0_DIF  LEVEL               TYPE                        ADMIN  \
# 0      FJI         0      2  Sovereign country                         Fiji
# 1      TZA         0      2  Sovereign country  United Republic of Tanzania
# 2      SAH         0      2      Indeterminate               Western Sahara
# 3      CAN         0      2  Sovereign country                       Canada
# 4      US1         1      2            Country     United States of America
# ..     ...       ...    ...                ...                          ...
# 172    SRB         0      2  Sovereign country           Republic of Serbia
# 173    MNE         0      2  Sovereign country                   Montenegro
# 174    KOS         0      2  Sovereign country                       Kosovo
# 175    TTO         0      2  Sovereign country          Trinidad and Tobago
# 176    SDS         0      2  Sovereign country                  South Sudan
#
#     ADM0_A3  ...                    NAME_KO                       NAME_NL  \
# 0       FJI  ...                     í¼ì§                          Fiji
# 1       TZA  ...               íìëì                      Tanzania
# 2       SAH  ...               ìì¬íë¼             Westelijke Sahara
# 3       CAN  ...                  ìºëë¤                        Canada
# 4       USA  ...                     ë¯¸êµ­  Verenigde Staten van Amerika
# ..      ...  ...                        ...                           ...
# 172     SRB  ...               ì¸ë¥´ë¹ì                       ServiÃ«
# 173     MNE  ...            ëª¬í
# ë¤ê·¸ë¡                    Montenegro
# 174     KOS  ...                  ì½ìë³´                        Kosovo
# 175     TTO  ...  í¸ë¦¬ëë¤ë í ë°ê³             Trinidad en Tobago
# 176     SDS  ...                  ë¨ìë¨                   Zuid-Soedan
#
#                NAME_PL            NAME_PT  \
# 0               FidÅ¼i               Fiji
# 1             Tanzania          TanzÃ¢nia
# 2     Sahara Zachodnia    Saara Ocidental
# 3               Kanada            CanadÃ¡
# 4    Stany Zjednoczone     Estados Unidos
# ..                 ...                ...
# 172             Serbia            SÃ©rvia
# 173        CzarnogÃ³ra         Montenegro
# 174             Kosowo             Kosovo
# 175  Trynidad i Tobago  Trinidad e Tobago
# 176  Sudan PoÅudniowy      SudÃ£o do Sul
#
#                                               NAME_RU              NAME_SV  \
# 0                                          Ð¤Ð¸Ð´Ð¶Ð¸                 Fiji
# 1                                    Ð¢Ð°Ð½Ð·Ð°Ð½Ð¸Ñ             Tanzania
# 2                       ÐÐ°Ð¿Ð°Ð´Ð½Ð°Ñ Ð¡Ð°Ñ
# Ð°ÑÐ°          VÃ¤stsahara
# 3                                        ÐÐ°Ð½Ð°Ð´Ð°               Kanada
# 4    Ð¡Ð¾ÐµÐ´Ð¸Ð½ÑÐ½Ð½ÑÐµ Ð¨ÑÐ°ÑÑ ÐÐ¼ÐµÑÐ¸ÐºÐ¸                  USA
# ..                                                ...                  ...
# 172                                      Ð¡ÐµÑÐ±Ð¸Ñ              Serbien
# 173                              Ð§ÐµÑÐ½Ð¾Ð³Ð¾ÑÐ¸Ñ           Montenegro
# 174                 Ð ÐµÑÐ¿ÑÐ±Ð»Ð¸ÐºÐ° ÐÐ¾ÑÐ¾Ð²Ð¾               Kosovo
# 175                  Ð¢ÑÐ¸Ð½Ð¸Ð´Ð°Ð´ Ð¸ Ð¢Ð¾Ð±Ð°Ð³Ð¾  Trinidad och Tobago
# 176                             Ð®Ð¶Ð½ÑÐ¹ Ð¡ÑÐ´Ð°Ð½             Sydsudan
#
#                           NAME_TR              NAME_VI                NAME_ZH  \
# 0                            Fiji                 Fiji                 ææ¿
# 1                        Tanzanya             Tanzania           å¦æ¡å°¼äº
# 2                     BatÄ± Sahra          TÃ¢y Sahara           è¥¿æåæ
# 3                          Kanada               Canada              å æ¿å¤§
# 4    Amerika BirleÅik Devletleri             Hoa Ká»³                 ç¾å½
# ..                            ...                  ...                    ...
# 172                    SÄ±rbistan               Serbia           å¡å°ç»´äº
# 173                      KaradaÄ           Montenegro        èç¹å
# §å¥ç¾
#
# 174                        Kosova               Kosovo              ç§ç´¢æ²
# 175            Trinidad ve Tobago  Trinidad vÃ  Tobago  åééåæå·´å¥
# 176                  GÃ¼ney Sudan            Nam Sudan              åèä¸¹
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 95 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### STEP 3: Group / aggregate the temperature anomaly data by country, year
# - For simplicity, we're only interested in yearly averages

# %%
gdf = gpd.read_file(SHAPEFILE)[['ADMIN', 'geometry']]
gdf.columns = ['country', 'geometry']
df = df.groupby(['country', 'year'])[['monthly_anomaly']].mean().reset_index()

# %% [markdown]
# ### STEP 4: Merge Data Sets.
# - We want to have our temperature data and geometric data in one place.
# - **Make sure you're still left with a GeoDataFrame at the end!**
#     - otherwise, if the resulting object is a regular Pandas dataframe, the ``.to_json()`` export will produce a normal ``.json`` file rather than a specialized ``.geojson`` file.
#     - A geojson file is very similar to a json file, with the exception that it's a bit more strict and specialized and works better with plotting libraries that usually expect the data to be in that format.

# %%
gdf = pd.merge(left=gdf, right=df, how='left', on='country')

# %%
gdf.head()
# Out:
#   country                                           geometry    year  \
# 0    Fiji  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  1900.0
# 1    Fiji  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  1901.0
# 2    Fiji  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  1902.0
# 3    Fiji  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  1903.0
# 4    Fiji  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  1904.0
#
#    monthly_anomaly
# 0        -0.779583
# 1        -0.763000
# 2        -1.068083
# 3        -0.409333
# 4        -0.826417

# %% [markdown]
# ---
# ---
# ### Time for Visualization with Folium

# %% [markdown]
# ### STEP 5: Plot data on a map for a single year (we can make it interactive later)

# %% [markdown]
#    ### 5a. Generate a blank canvas / figure.

# %%
import folium

# %%
basemap = folium.Map(location=[52.54, 13.36],
                zoom_start=2,
                tiles='CartoDB positron') #try out the other options!

# %%
basemap #display the map directly in Jupyter!
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 5a. Generate a GeoJSON string for a single year.
# - The Folium library (as well as many other JavaScript-based mapping libraries) requires the data to be in GeoJSON format.
#     - **HINT**: How can you convert a GeoDataFrame into a GeoJSON? Think of how you might do this in regular pandas.
# - Let's use the year 2000 as an example.

# %%
gdf_2000 = gdf[gdf['year'] == 2000]
json_2000 = gdf_2000.to_json()

# %%
gdf_2000
# Out:
#                            country  \
# 100                           Fiji
# 214    United Republic of Tanzania
# 328                 Western Sahara
# 442                         Canada
# 556       United States of America
# ...                            ...
# 18930       Bosnia and Herzegovina
# 19044                    Macedonia
# 19158           Republic of Serbia
# 19272                   Montenegro
# 19387          Trinidad and Tobago
#
#                                                 geometry    year  \
# 100    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...  2000.0
# 214    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...  2000.0
# 328    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...  2000.0
# 442    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...  2000.0
# 556    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...  2000.0
# ...                                                  ...     ...
# 18930  POLYGON ((18.56000 42.65000, 17.67492 43.02856...  2000.0
# 19044  POLYGON ((22.38053 42.32026, 22.88137 41.99930...  2000.0
# 19158  POLYGON ((18.82982 45.90887, 18.82984 45.90888...  2000.0
# 19272  POLYGON ((20.07070 42.58863, 19.80161 42.50009...  2000.0
# 19387  POLYGON ((-61.68000 10.76000, -61.10500 10.890...  2000.0
#
#        monthly_anomaly
# 100           0.638000
# 214           0.457417
# 328           0.611750
# 442           0.891583
# 556           0.856417
# ...                ...
# 18930         1.599750
# 19044         1.022000
# 19158         1.633500
# 19272         1.180500
# 19387         0.233750
#
# [171 rows x 4 columns]

# %%
json_2000
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "100", "type": "Feature", "properties": {"country": "Fiji", "monthly_anomaly": 0.638, "year": 2000.0}, "geometry": {"type": "MultiPolygon", "coordinates": [[[[180.0, -16.067132663642447], [180.0, -16.555216566639196], [179.36414266196414, -16.801354076946883], [178.72505936299711, -17.01204167436804], [178.59683859511713, -16.639150000000004], [179.0966093629971, -16.433984277547403], [179.4135093629971, -16.379054277547404], [180.0, -16.067132663642447]]], [[[178.12557, -17.50481], [178.3736, -17.33992], [178.71806, -17.62846], [178.55271, -18.15059], [177.93266000000003, -18.28799], [177.38146, -18.16432], [177.28504, -17.72465], [177.67087, -17.381140000000002], [178.12557, -17.50481]]], [[[-179.79332010904864, -16.020882256741224], [-179.9173693847653, -16.501783135649397], [-180.0, -16.555216566639196], [-180.0, -16.067132663642447], [-179.79332010904864, -16.020882256741224]]]]}}, {"id": "214", "type": "Feature", "properties": {"country": "United Republic of Tanzania", "monthly_anomaly": 0.45741666666666664, "year": 2000.0}, "geometry": {"type": "Polygon", "coordinates": [[[33.90371119710453, -0.9500000000000001], [34.07261999999997, -1.0598199999999451], [37.69868999999994, -3.0969899999999484], [37.7669, -3.6771200000000004], [39.20222, -4.67677], [38.74053999999995, -5.9089499999999475], [38.79977000000008, -6.475660000000005], [39.44, -6.839999999999861], [39.47000000000014, -7.099999999999966], [39.19468999999998, -7.703899999999976], [39.25203000000005, -8.00780999999995], [39.18652000000009, -8.48550999999992], [39.53574000000009, -9.112369999999885], [39.94960000000003, -10.098400000000026], [40.316586229110854, -10.317097752817492], [40.31659000000002, -10.317099999999868], [39.52099999999996, -10.89688000000001], [38.42755659358775, -11.285202325081656], [37.827639999999974, -11.26878999999991], [37.471289999999954, -11.568759999999997], [36.775150994622805, -11.594537448780805], [36.51408165868426, -11.720938002166735], [35.31239790216904, -11.439146416879147], [34.55998904799935, -11.520020033415925], [34.27999999999997, -10.160000000000025], [33.940837724096525, -9.693673841980285], [33.73972000000009, -9.417149999999992], [32.75937544122132, -9.23059905358906], [32.19186486179194, -8.930358981973257], [31.556348097466497, -8.762048841998642], [31.15775133695005, -8.594578747317366], [30.740009731422095, -8.34000593035372], [30.74001549655179, -8.340007419470915], [30.199996779101696, -7.079980970898163], [29.620032179490014, -6.520015150583426], [29.419992710088167, -5.939998874539434], [29.519986606572928, -5.419978936386315], [29.339997592900346, -4.4999834122940925], [29.753512404099865, -4.452389418153302], [30.11632000000003, -4.090120000000013], [30.505539999999996, -3.5685799999999404], [30.752240000000086, -3.3593099999999936], [30.743010000000027, -3.034309999999948], [30.527660000000026, -2.807619999999986], [30.469673645761223, -2.41385475710134], [30.469670000000008, -2.4138299999999617], [30.75830895358311, -2.2872502579883687], [30.816134881317712, -1.6989140763453887], [30.419104852019245, -1.1346591121504161], [30.769860000000108, -1.0145499999999856], [31.866170000000068, -1.0273599999999306], [33.90371119710453, -0.9500000000000001]]]}}, {"id": "328", "type": "Feature", "properties": {"country": "Western Sahara", "monthly_anomaly": 0.6117499999999999, "year": 2000.0}, "geometry": {"type": "Polygon", "coordinates": [[[-8.665589565454809, 27.656425889592356], [-8.665124477564191, 27.589479071558227], [-8.684399786809053, 27.395744126896005], [-8.6872936670174, 25.881056219988906], [-11.96941891117116, 25.933352769468268], [-11.937224493853321, 23.374594224536168], [-12.874221564169575, 23.284832261645178], [-13.118754441774712, 22.771220201096256], [-12.929101935263532, 21.327070624267563], [-16.845193650773993, 21.33332347257488], [-17.06342322434257, 20.999752102130827], [-17.02042843267577, 21.422310288981578], [-17.00296179856109, 21.420 ...

# %% [markdown]
# ### STEP 6: Generate an interactive choropleth map of the data for a single year
# - Use the convenient ``folium.Choropleth()`` class to generate interactive tiles, which we can overlay on top of our base map!
# - The trick to get it working is to make sure that the Choropleth layer understands which column from the dataframes is supposed to be mapped to which key in the JSON string in order for the data to render properly.

# %%
tiles = folium.Choropleth(
            geo_data=json_2000,                 # geojson string that includes the geo data (for the year 2000)
            name="2000 Data",                   # just a title
            data=gdf_2000,                      # dataframe that includes the data (for the year 2000)
            columns=['country','monthly_anomaly'], # names of the columns to include from the dataframe
            key_on='properties.country',        # name of JSON key within the "properties" value that contains country names
            fill_color='YlGnBu',                # play around with the rest of the aesthetic options
            nan_fill_color='black',         
            fill_opacity=0.8,
            line_opacity=0.1,
            legend_name='Monthly Temperature Anomaly', # Name of variable for the colour bar.
            highlight=True,
        )

# %%
tiles.add_to(basemap) #add the layer to the blank canvas / figure

# %%
basemap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### STEP 7: Add additional features to the map!
# Some ideas:
# - **Tooltip (info tip) highlighting** (included here)
# - Adding other layers / markers
# - Making the tiles "clickable"
# - Make the legend a fixed size
# - The documentation isn't *great*, but with enough persistence / looking at examples online (some pretty good tutorials out there) / reading forums, you can add nice little widgets and extra interactivity to your map!

# %%
style_html = "font-size: 10px; font-weight: small" #add a little bit of HTML, if you know some.

tooltip = folium.features.GeoJsonTooltip(fields = ['country','monthly_anomaly'],
                                         style = style_html)

# %%
tiles.geojson.add_child(tooltip)
#overwrite some of the original properties of the geojson attribute of the tile

# %%
basemap #the map should now display information whenever you hover over a country tile!
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### STEP 8: Export the figure to an HTML file, so you can open it in your web browser!
# - The reason the figure is interactive (e.g. you can zoom around, it has hover effects, etc.) is because there's a of front-end (i.e. client-side) JavaScript code that Plotly creates for you automatically.
# - Use the ``.save()`` method to export the file and open it up in a web browser.
#     - Bonus: Open the ``.html`` file in a text editor and see if you can understand any of it :)

# %%
basemap.save("2000_map.html")

# %%
#bash command to open the file (should use your web browser by default)
# !open 2000_map.html

# %% [markdown]
# ---

# %% [markdown]
# ### And that's it!
# - Unfortunately, there doesn't seem to be an easy way to add interactive sliders to the map (e.g. to change frames / years) like how you can do it in Plotly or Bokeh (at least, not as far as I could find).
#     - Folium is pretty easy to use to make interactive maps quickly, but it seems to be lacking for more advanced features. The library is meant to be a bit more minimal / lightweight (which is also great, depending on your use case!)
#     - You can, of course, write your own for-loop to generate multiple files for different years, but if you really want to add animation, you either have to write your own custom JavaScript (probably not a reasonable option) or switch over to a more powerful visualization library like Plotly or Bokeh.
#     - However, there seem to be enough pretty good Folium tutorials / examples online where people have been able to make some pretty amazing things.
