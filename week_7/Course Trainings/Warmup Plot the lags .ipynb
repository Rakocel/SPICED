# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/arma_process.csv')

# %%
df
# Out:
#      remainder
# 0     1.668068
# 1     3.594771
# 2     4.674503
# 3     3.665661
# 4     3.496006
# ..         ...
# 127   3.277818
# 128   3.617415
# 129   4.035193
# 130   3.532804
# 131   3.810848
#
# [132 rows x 1 columns]

# %%
# plot
plt.rcParams['figure.figsize'] = (15,5)
df.plot()
plt.ylabel('remainder')
# Out:
# Text(0, 0.5, 'remainder')

# %%
plot_pacf
