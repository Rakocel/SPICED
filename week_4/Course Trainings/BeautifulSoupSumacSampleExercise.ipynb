# %% [markdown]
# ## Using BeautifulSoup

# %% [markdown]
# **Task:** From the [SPICED Academy homepage](https://www.spiced-academy.com/), extract the following paragraph using web-scraping:
# - "Unlock the power of data with our immersive Data Science bootcamp"

# %% [markdown]
# *Tip:*
# - Use a nice browser that allows you to easily view the HTML code side-by-side with the webpage.
#     - For example, in Google Chrome, you can right-click (or ctrl+click) a webpage and click '*View Page Source*'
#     - You can also click '*Inspect*' to get a more interactive comparison of the HTML code that corresponds to a section of the website you're interested in.

# %% [markdown]
# - JSON -- data structure typical of APIs
#     - cleaner data, easier to parse
# - HTML -- markup language used to structure web pages
#     - messier data, requires specialized tools to parse

# %% [markdown]
# ### Step 1. Get the HTML text from a website

# %% [markdown]
# There are multiple ways to get to the solution!
#
# ``.find()`` always returns the first instance of your 'query'.
#
# ``.find_all()`` returns a list-like object (called a "ResultSet") that contains at least one matching result.
#
# ``.text`` returns the actual part of the tag that is outside of the < angled brackets > (i.e. the text)

# %% [markdown]
# #### Download the html from a web page using the requests module.

# %%
import requests
import re
import pandas as pd

response = requests.get('https://www.spiced-academy.com/')
spiced_html = response.text
print(type(spiced_html) ,response)
# Out:
# <class 'str'> <Response [200]>

# %%
print(spiced_html)
# Out:
# <!DOCTYPE html>
# <html lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" dir="ltr">
#
# <head>
#     <title>Your new career starts here | Spiced Academy</title>
#     <meta name="description" content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science.">
#
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <link href="https://fonts.googleapis.com/css?family=Poppins:300,400,600&display=swap" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=IBM+Plex+Mono:400,500&display=swap" rel="stylesheet">
#     <link rel='stylesheet' href='/css/main.css'>
#     <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png?v=3">
#     <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png?v=3">
#     <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png?v=3">
#     <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#5bbad5">
#     <meta name="msapplication-TileColor" content="#da532c">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="google-site-verification" content="DICJgJwgfNeeiq66MAwDzpaeqBBgDqZsBNFBMwVtoaY">
#     <meta name="theme-color" content="#2E016D" />
#
#
#     <meta name="robots" content="noodp">
#     <link rel="canonical" href="https://www.spiced-academy.com/en">
#     <link rel="alternate" href="https://www.spiced-academy.com/en/" hreflang="en" />
#     <link rel="alternate" href="https://www.spiced-academy.com/de/" hreflang="de" />
#
#
#     <meta property="og:locale" content="en_US">
#     <meta property="og:type" content="article">
#     <meta property="og:title" content="Spiced Academy | Your new career starts here">
#     <meta property="og:description"
#       content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science.">
#     <meta property="og:url" content="https://www.spiced-academy.com/">
#     <meta property="og:site_name" content="Spiced Academy">
#     <meta property="article:publisher" content="https://www.facebook.com/spicedacademy">
#     <meta property="fb:app_id" content="1214485688610932">
#     <meta property="og:image" content="https://www.spiced-academy.com/img/people/spiced_share.jpg">
#     <meta name="twitter:card" content="summary_large_image">
#     <meta name="twitter:description" content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science.">
#     <meta name="twitter:title" content="Your new career starts here | Spiced Academy – A Coding Academy in Berlin">
#     <meta name="twitter:site" content="@SPICEDacademy">
#     <meta name="twitter:image" content="https://www.spiced-academy.com/img/people/spiced_share.jpg">
#     <meta name="twitter:creator" content="@SPICEDacademy">
#
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=UA-78282401-1"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag() { dataLayer.push(arguments); }
#       gtag('js', new Date());
#       gtag('config', 'UA-78282401-1');
#       gtag('config', 'AW-882057422');
#     </script>
#
#
#
#
#
#     <!-- Facebook Pixel Code -->
#     <script>
#       !function (f, b, e, v, n, t, s) {
#         if (f.fbq) return; n = f.fbq = function () {
#           n.callMethod ?
#             n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#         };
#         if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#         n.queue = []; t = b.createElement(e); t.async = !0;
#         t.src = v; s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s)
#       }(window, document, 'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '1628135084116192');
#       fbq('track', 'PageView');
#     </script>
#     <noscript>
#       <img height="1" width="1" src="https://www.facebook.com/tr?id=1628135084116192&ev=PageView
#     &noscript=1" />
#     </noscript>
#     <!-- End Facebook Pixel Code -->
#
#
#     <!-- DO NOT MODIFY -->
#     <script>
#       var i = new Image(); i.src = "https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=";
#     </script>
#     <noscript>
#       <img height="1" width="1" style="display:none" src="https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=
#     https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=
#     " />
#     </noscript>
#     <!-- End Reddit Conversion Pixel -->
#
# </head>
#
# <body>
#
#     <header>
#         <div class="header-left">
#             <a href="/">
#                 <img class="header-logo" src="/img/Spiced_Logo_Dark.svg" alt="Spiced logo">
#             </a>
#             <div class="header-links">
#                 <ul class="top-level-menu">
#                     <li>
#                         <a href="/program">PROGRAMS</a>
#                         <ul class="dropdown">
#                             <li><a href="/program/full-stack-web-development">Web Development</a></li>
#                             <li><a href="/program/data-science">Data Science</a></li>
#                             <li><a href="/program/data-analytics">Data Analytics</a></li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="#">LOCATIONS</a>
#                         <ul class="dropdown">
#                             <li><a href="/berlin">Berlin</a></li>
#                             <li><a href="/hamburg">Hamburg</a></li>
#                             <li><a href="/cologne">Cologne</a></li>
#                             <li><a href="/stuttgart">Stuttgart</a></li>
#                         </ul>
#                     </li>
#                 </ul>
#                 <a href="/apply" class="apply-now">
#                     APPLY NOW
#                 </a>
#             </div>
#         </div>
#
#         <div class="header-right">
#             <div class="header-links fade-header">
#
#
#             </div>
#                 <p class="js-language-toggle language-toggle">
#                     <a style='font-weight:100;' href='/lng/de'>DE</a> | <a style='font-weight:900;'  href='/lng/en'>EN</a>
#                 </p>
#             <div id="nav-icon">
#                 <span></span>
#                 <span></span>
#             </div>
#         </div>
#
#         <div class="header-sidebar-container">
#             <div class="nav-links-container">
#                 <div>
#                     <h4 class="lighter">
#                         <a href="/program">Programs</a>
#                         <span class="toggler-open"></span>
#                     </h4>
#                     <ul class="toggler-open">
#                         <li>
#                             <a href="/program/full-stack-web-development">Web Development</a>
#                         </li>
#                         <li>
#                             <a href="/program/data-science">Data Science</a>
#                         </li>
#                         <li>
#                             <a href="/program/data-analytics">Data Analytics</a>
#                         </li>
#                     </ul>
#                 </div>
#                 <div>
#                     <h4 class="lighter">
#                         <a href="#">Locations</a>
#                         <span></span>
#                     </h4>
#                     <ul>
#                         <li>
#                             <a href="/berlin">Berlin</a>
#                         </li>
#                         <li>
#                             <a href="/hamburg">Hamburg</a>
#                         </li>
#                         <li>
#                             <a href="/cologne">Cologne</a>
#                         </li>
#                         <li>
#                             <a href="/stuttgart">Stuttgart</a>
#                         </li>
#                     </ul>
#                 </div>
#
#                 <ul>
#                     <li>
#                         <a href="/about">About</a>
#                     </li>
#                     <li>
#                         <a href="/financing">Financing</a>
#                     </li>
#                 </ul>
#                 <ul>
#                     <li>
#                         <a href="/graduates">Graduates</a>
#                     </li>
#                     <li>
#                         <a href="/outcomes">Outcomes</a>
#                     </li>
#                     <li>
#                         <a href="/hiring">Hire a Spicedling</a>
#                     </li>
#                     <li>
#                         <a href="/faq">FAQ</a>
#                     </li>
#                     <li>
#                         <a href="https://blog.spiced-academy.com/" target="_blank">Blog</a>
#                     </li>
#                 </ul>
#                 <div class="apply-nav-container">
#                     <a href="/apply" class="apply-now">
#                         APPLY NOW
#                     </a>
#                 </div>
#             </div>
#         </div>
#     </header>
#
#     <div class="scroll-container">
#         <section class="js-header-left-dark js-header-right-light mob-col-reverse">
#
#     <div class="panel v-center-h-end v-center-h-center--mob">
#         <div class="text-container text-container--mob-center">
#             <h1 class="main-heading main-heading--future ">
#
#                     Your future in tech
#             </h1>
#             <h3 class="sub-heading ">Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science.</h3>            <a href="/program">
#                 <button class="btn btn--primary">Start your journey</button>
#             </a>
#         </div>
#     </div>
#
#     <div class="panel bg-color-primary-light duel-background panel-center">
#         <div class="circle-image-container">
#             <div class="circle-half circle-half--left"
#                 style="background-image: url(/img/people/coding_bootcamp_r_homepage_spiced.jpg); ">
#             </div>
#             <div class="top-right-circle circle-quarter bg-color-action">
#             </div>
#             <div class="bottom-right-circle circle-quarter bg-color-white"></div>
#         </div>    </div>
#
# </section>
#
# <section class="js-header-left-light js-header-right-light mob-bg-color-action-dark" id="start-journey">
#
#     <div class="panel">
#         <img
#             class="single-panel-image student-built-image"
#             src="/img/people/spiced-academy-homepage-2.jpg"
#             alt="spiced student"
#         >    </div>
#
#     <div
#         class="panel bg-color-action flex-center ">
#         <div class="triangle-top-right triangle-top-right--action "></div>
#         <div class="text-container text-container--simple ">
#             <h1 class="main-heading main-heading--space-bottom main-heading--secondary main-heading--space-bottom">
#                 Your new career starts here
#
#             </h1>
#
#             <div class="career-start-container--subheading-container">
#                 <div class="shape-box-small small-shape-spacer-container">
#                     <div class="shape-box-small--triangle-top-right"></div>
#                 </div>
#                 <div>
#                             <h4 class="">
#                                 Get all the tools you need to enter today’s tech job market
#                             </h4>
#
#                     <p class="">Whether you’re looking to level up or switch fields entirely, Spiced gives you the skills to get hired. Build a portfolio full of real-life projects using the most in-demand technologies on the market - ready to impress any hiring manager.</p>
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>
# </section>
#
#     <section class="js-header-left-light js-header-right-dark">
#         <div class="panel bg-color-primary-light v-center-h-center v-center-h-center--color-white v-center-h-center--mob-left">
#             <div class="triangle-top-left-action city"></div>
#             <div class="text-container text-container--simple city">
#                 <h1 class="main-heading  ">
#
#                         Our Programs
#                 </h1>
#                 <h3 class="sub-heading ">Join 900+ Spicedlings and take the leap into tech</h3>            </div>
#         </div>
#         <div class="panel bg-color-white v-center-h-center city">
#             <div class="city-cohort-dates">
#                 <div>
#                     <details>
#                         <summary>
#                             Web Development
#                         </summary>
#                             <p>Get all the skills you need to kickstart your career in Web Development.</p>
#                             <p class="bold next-cohort">Courses in Berlin, Cologne, Hamburg, Stuttgart</p>
#                             <a href="/program/full-stack-web-development">
#                                 <button class="btn btn--thin btn--secondary">Read more</button>
#                             </a>
#                     </details>
#                 </div>
#                 <div>
#                     <details>
#                         <summary>
#                             Data Science
#                         </summary>
#                             <p>Unlock the power of data with our immersive Data Science bootcamps.</p>
#                             <p class="bold next-cohort">Courses in Berlin, Cologne, Hamburg, Stuttgart</p>
#                             <a href="/program/data-science">
#                                 <button class="btn btn--thin btn--secondary">Read more</button>
#                             </a>
#                     </details>
#                 </div>
#                 <div>
#                     <details>
#                         <summary>
#                             Data Analytics
#                         </summary>
#                             <p>Get a jump-start into the world of data processing with our 9-week Data Analytics bootcamp.</p>
#                             <p class="bold next-cohort">Courses in Berlin</p>
#                             <a href="/program/data-analytics">
#                                 <button class="btn btn--thin btn--secondary">Read more</button>
#                             </a>
#                     </details>
#                 </div>
#             </div>
#         </div>
#     </section>
#
# <section class="js-header-left-light js-header-right-light">
#
#     <div class="panel mob-one-third-panel mob-bg-color-primary-light">
#         <div class="triple-image-container triple-image-container--two-images-mobile">
#             <img src=/img/people/spiced-academy-homepage-3.jpg alt="spiced-academy-homepage-3">
#             <img class="small-image" src=/img/people/spiced-academy-homepage-7.jpg alt="spiced-academy-homepage-7">
#             <img class="small-image" src=/img/people/spiced-academy-homepage-8.jpg alt="spiced-academy-homepage-6">
#         </div>    </div>
#
#     <div class="panel bg-color-primary-dark panel-employment mob-two-thirds-panel">
#         <div class="triangle-top-right triangle-top-right--primary"></div>
#         <div class="start-application-container">
#             <div class="employment-rate-container">
#                 <div class="employment-percentage">
#                     <div>
#                         <div class="main-text">4.7</div>
#                         <div class="sub-text">out of 5</div>
#                     </div>
#                 </div>
#                 <h3 class="sub-heading sub-heading--white">Average review on Course Report</h3>
#             </div>
#             <div class="award-container">
#                 <img src="/img/icons/best_coding_bootcamp_2019_white_v2.png" alt="course report award full stack">
#                 <img src="/img/icons/best_data_science_bootcamp_2019_white_v2.png"
#                     alt="course report award Data Science">
#             </div>
#         </div>
#
# </section>
#
# <section class="js-header-left-dark js-header-right-light mob-col-reverse">
#
#     <div class="panel bg-color-white mob-two-thirds-panel">
#         <div class='action-box action-box--right'>
#             <h1 class="main-heading main-heading--off-center-left main-heading--space-bottom">Career <br> Services</h1>
#             <div class="shape-box-small small-shape-spacer-container">
#                 <div class="shape-box-small--triangle-top-right-pink"></div>
#             </div>
#             <p class="bold mob-hidden">Practical, real-world approach</p>
#             <p class="mob-only career-mob-heading">Real-world technical interviews</p>
#             <p class="mob-hidden p-smaller">An extensive focus on passing real-world technical interviews.</p>
#             <div class="shape-box-small small-shape-spacer-container">
#                 <div class="shape-box-small--triangle-top-right-pink"></div>
#             </div>
#             <p class="bold mob-hidden">Tailored coaching sessions</p>
#             <p class="mob-only career-mob-heading">Tailored coaching sessions</p>
#             <p class="mob-hidden p-smaller">Unlimited one-to-one coaching sessions, helping you to develop professionally.</p>
#             <div class="shape-box-small small-shape-spacer-container">
#                 <div class="shape-box-small--triangle-top-right-pink"></div>
#             </div>
#             <p class="bold mob-hidden">More than just technical skills</p>
#             <p class="mob-only career-mob-heading">Professional development</p>
#             <p class="mob-hidden p-smaller">We&#x27;re here to support you with the personal changes in your career transition, too.</p>
#             <div class="shape-box-small small-shape-spacer-container">
#                 <div class="shape-box-small--triangle-top-right-pink"></div>
#             </div>
#             <p class="bold mob-hidden">An insider view</p>
#             <p class="mob-only career-mob-heading">An insider view</p>
#             <p class="mob-hidden p-smaller">We share the insider view of the the latest recruitment processes in Germany and beyond.</p>
#         </div>    </div>
#
#
#     <div class="panel">
#         <img
#             class="single-panel-image student-built-image"
#             src="/img/staff/career-services.jpg"
#             alt="career-services"
#         >    </div>
#
# </section>
#
# <section class="js-header-left-light js-header-right-light">
#
#     <div class="panel bg-color-white mob-hidden landscape-block">
#         <div class="three-quarter-panel">
#             <img
#                 class="single-panel-image student-built-image"
#                 src="/img/testimonials/main-testimonial-spiced.jpg"
#                 alt="alumni-raul-spiced"
#             >        </div>
#         <div class="">
#             <div class="our-students-work-at">
#                 <h4>Our students now work at:</h4>
#                 <div class="four-logo-container">
#                     <div class="company-logo-container">
#                         <img src="/img/company-logos/bcg-logo-grey.svg" alt="bcg">
#                     </div>
#                     <div class="company-logo-container">
#                         <img src="/img/company-logos/infarm-logo-grey.svg" alt="infarm">
#                     </div>
#                     <div class="company-logo-container">
#                         <img src="/img/company-logos/ebay-logo-grey.svg" alt="Ebay">
#                     </div>
#                     <div class="company-logo-container">
#                         <img src="/img/company-logos/wework-logo-grey.svg" alt="audible">
#                     </div>
#                 </div>
#
#             </div>
#         </div>
#     </div>
#
#     <div class="panel mob-full-panel">
#         <div class="half-panel bg-color-action">
#             <div class="quote-block">
#                 <p class="quotation-mark">"</p>
#                 <p class="quotation">I now have a job with great prospects, in a company which offers me a chance to learn and grow. Thanks to Spiced, my life has completely changed.</p>
#                 <p class="quotation-mark quotation-mark-bottom">"</p>
#                 <div class="student-name-job">
#                     <p class="student-name">Raul Iglesias</p>
#                     <p class="student-job">Web Developer at Push Creative Ventures</p>
#                 </div>
#             </div>        </div>
#         <div class="half-panel bg-color-action-dark"></div>
#     </div>
#
# </section>
#
# <section class="js-header-left-light js-header-right-dark full-height-section full-height-panels">
#
#     <div class="panel mob-smaller-panel mob-top-header-padding">
#         <div class="based-in-half-panel  bg-color-primary-light panel-bottom">
#             <h2 class="panel-text-overlap">Spiced is <br>based in...</h2>
#         </div>
#         <div class="based-in-half-panel bg-color-primary-dark"></div>
#     </div>
#
#     <div class="panel">
#         <div class="cities-container">
#             <a href="/berlin" class="city-container">
#                 <div class="city-icon-container city-icon-container--dark">
#                     <img class="city-icon" src="/img/icons/berlin-icon.svg" alt="Berlin icon">
#                 </div>
#
#                 <p>Berlin</p>
#             </a>
#
#             <a href="/hamburg" class="city-container">
#                 <div class="city-icon-container city-icon-container--dark">
#                     <img class="city-icon" src="/img/icons/hamburg-icon.svg" alt="Hamburg icon">
#                 </div>
#
#                 <p>Hamburg</p>
#             </a>
#
#             <a href="/cologne" class="city-container">
#                 <div class="city-icon-container city-icon-container--light">
#                     <img class="city-icon" src="/img/icons/cologne-icon.svg" alt="Cologne icon">
#                 </div>
#
#                 <p>Cologne</p>
#             </a>
#
#             <a href="/stuttgart" class="city-container stuttgart">
#                 <div class="city-icon-container city-icon-container--light ">
#                     <img class="city-icon" src="/img/icons/stuttgart-icon.svg" alt="stuttgart icon">
#                 </div>
#
#                 <p>Stuttgart</p>
#             </a>
#         </div>
#     </div>
#
# </section>
#
# <section class="js-header-left-dark js-header-right-dark graduate-testimonials">
#
#     <div
#         class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-0 js-carousel-slide-0 js-carousel-slide-0  fade-in ">
#         <div class="circle-image-container">
#             <div class="circle-half circle-half--left"
#                 style="background-image: url(/img/testimonials/alumni-parinaz-spiced.jpg); ">
#             </div>
#             <div class="top-right-circle circle-quarter bg-color-pink">
#                 <div class="next-link-container">
#                     <p class="link js-next js-btn">Next</p>
#                     <div class="shape-box-small small-shape-spacer-container">
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                     </div>
#                 </div>
#             </div>
#             <div class="bottom-right-circle circle-quarter bg-color-action"></div>
#         </div></div>
#
#
#     <div
#         class="panel flex-center js-carousel-slide-0  fade-in ">
#         <div class=" "></div>
#         <div class="text-container text-container--simple text-container--center-short-txt">
#             <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
#
#             <div class="career-start-container--subheading-container">
#                 <div class="shape-box-small small-shape-spacer-container">
#                     <div class="shape-box-small--triangle-top-right"></div>
#                 </div>
#                 <div>
#                             <h4 class="sub-heading sub-heading--primary-light">
#                                 Parinaz Roghany<br>Full Stack Web Developer at Ebay
#                             </h4>
#
#                     <p class="text-container-height">I wanted to learn JavaScript and Spiced’s Full Stack program sounded great. It was so cool learning all these things like real-time chatting and building your own online social media platform.</p>
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>    <div
#         class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-1 js-carousel-slide-1 js-carousel-slide-1  fade-out ">
#         <div class="circle-image-container">
#             <div class="circle-half circle-half--left"
#                 style="background-image: url(/img/testimonials/alumni-kent-spiced.jpg); ">
#             </div>
#             <div class="top-right-circle circle-quarter bg-color-pink">
#                 <div class="next-link-container">
#                     <p class="link js-next js-btn">Next</p>
#                     <div class="shape-box-small small-shape-spacer-container">
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                     </div>
#                 </div>
#             </div>
#             <div class="bottom-right-circle circle-quarter bg-color-action"></div>
#         </div></div>
#
#
#     <div
#         class="panel flex-center js-carousel-slide-1  fade-out ">
#         <div class=" "></div>
#         <div class="text-container text-container--simple text-container--center-short-txt">
#             <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
#
#             <div class="career-start-container--subheading-container">
#                 <div class="shape-box-small small-shape-spacer-container">
#                     <div class="shape-box-small--triangle-top-right"></div>
#                 </div>
#                 <div>
#                             <h4 class="sub-heading sub-heading--primary-light">
#                                 Kent Troutman<br>Data Scientist at Deutsche Bundesbank
#                             </h4>
#
#                     <p class="text-container-height">The intense method of the boot camp helped me get to the next level skill-wise. I kept up my end and worked hard, as did my classmates, and Kristian made sure that no one was left behind.</p>
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>    <div
#         class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-2 js-carousel-slide-2 js-carousel-slide-2  fade-out ">
#         <div class="circle-image-container">
#             <div class="circle-half circle-half--left"
#                 style="background-image: url(/img/testimonials/alumni-olof-spiced.jpg); ">
#             </div>
#             <div class="top-right-circle circle-quarter bg-color-pink">
#                 <div class="next-link-container">
#                     <p class="link js-next js-btn">Next</p>
#                     <div class="shape-box-small small-shape-spacer-container">
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                     </div>
#                 </div>
#             </div>
#             <div class="bottom-right-circle circle-quarter bg-color-action"></div>
#         </div></div>
#
#
#     <div
#         class="panel flex-center js-carousel-slide-2  fade-out ">
#         <div class=" "></div>
#         <div class="text-container text-container--simple text-container--center-short-txt">
#             <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
#
#             <div class="career-start-container--subheading-container">
#                 <div class="shape-box-small small-shape-spacer-container">
#                     <div class="shape-box-small--triangle-top-right"></div>
#                 </div>
#                 <div>
#                             <h4 class="sub-heading sub-heading--primary-light">
#                                 Olof Reimegård<br>Full Stack Web Developer at Zaplox
#                             </h4>
#
#                     <p class="text-container-height">I made the decision to do the course and since the first day I haven&#x27;t looked back. The curriculum feels tailored for the job and is constantly updated to match the fast changing job market. If you feel willing and ready to really dive into coding then this course is for you.</p>
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>    <div
#         class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-3 js-carousel-slide-3 js-carousel-slide-3  fade-out ">
#         <div class="circle-image-container">
#             <div class="circle-half circle-half--left"
#                 style="background-image: url(/img/testimonials/alumni-lilian-spiced.jpg); ">
#             </div>
#             <div class="top-right-circle circle-quarter bg-color-pink">
#                 <div class="next-link-container">
#                     <p class="link js-next js-btn">Next</p>
#                     <div class="shape-box-small small-shape-spacer-container">
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                     </div>
#                 </div>
#             </div>
#             <div class="bottom-right-circle circle-quarter bg-color-action"></div>
#         </div></div>
#
#
#     <div
#         class="panel flex-center js-carousel-slide-3  fade-out ">
#         <div class=" "></div>
#         <div class="text-container text-container--simple text-container--center-short-txt">
#             <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
#
#             <div class="career-start-container--subheading-container">
#                 <div class="shape-box-small small-shape-spacer-container">
#                     <div class="shape-box-small--triangle-top-right"></div>
#                 </div>
#                 <div>
#                             <h4 class="sub-heading sub-heading--primary-light">
#                                 Lilian van Someren Greve<br>Junior Data Scientist at TeamViewer
#                             </h4>
#
#                     <p class="text-container-height">Having worked in Business Intelligence, Spiced was able to bridge the gaps in my knowledge regarding Python and a deeper understanding of how some key Data Science models work. You can learn an amazing amount in 3 months, if you&#x27;re willing to.</p>
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>    <div
#         class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-4 js-carousel-slide-4 js-carousel-slide-4  fade-out ">
#         <div class="circle-image-container">
#             <div class="circle-half circle-half--left"
#                 style="background-image: url(/img/testimonials/alumni-alex-spiced.jpg); ">
#             </div>
#             <div class="top-right-circle circle-quarter bg-color-pink">
#                 <div class="next-link-container">
#                     <p class="link js-next js-btn">Next</p>
#                     <div class="shape-box-small small-shape-spacer-container">
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                         <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
#                     </div>
#                 </div>
#             </div>
#             <div class="bottom-right-circle circle-quarter bg-color-action"></div>
#         </div></div>
#
#
#     <div
#         class="panel flex-center js-carousel-slide-4  fade-out ">
#         <div class=" "></div>
#         <div class="text-container text-container--simple text-container--center-short-txt">
#             <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
#
#             <div class="career-start-container--subheading-container">
#                 <div class="shape-box-small small-shape-spacer-container">
#                     <div class="shape-box-small--triangle-top-right"></div>
#                 </div>
#                 <div>
#                             <a class="sub-heading external-link" href="https://www.seoberlino.com/en" target="_blank"
#                                 rel="noopener noreferrer">
#                                 Alex Bieth<br>Freelance Consultant at SEO Berlino
#                             </a>
#
#                     <p class="text-container-height">Challenging and extremely rewarding - Spiced gave me the skills needed to become a Full Stack Web Developer. I have been coding every day since I finished the course!</p>
#
#
#                 </div>
#             </div>
#
#         </div>
#     </div>    <script src="/js/carousel.js"></script>
#     <script src="/js/details-summary.js"></script>
#
# </section>
#
#         <section id="contact-us"   class="mob-bg-color-primary-dark"  >
#             <footer >
#                     <div class="footer-top-container mob-smaller-panel mob-top-panel">
#                         <div class="panel-footer panel-footer--flex">
#                             <div class="footer-top-panel">
#                                 <div class='mob-hidden'>
#                                     <h2>Questions?</h2>
#                                     <p class='sub-heading sub-heading--grey'>You can head to our <a href='/faq'>FAQ</a> page or...</p>
#                                 </div>
#                                 <a href="https://calendly.com/spicedacademy/15min?month=2020-02" rel="nofollow noopener" target="_blank">
#                                     <button class='btn btn--primary'>Schedule a Chat</button>
#                                 </a>
#                             </div>
#
#                         </div>
#
#                         <div class='panel-footer panel-footer--flex bg-color-primary-light'>
#                             <div class="footer-top-panel footer-top-panel--white">
#                                 <div class='mob-hidden'>
#                                     <h2 class='lighter'>Ready?</h2>
#                                     <p class='sub-heading'>Take the leap and begin your application online.</p>
#                                 </div>
#                                 <a href="/apply">
#                                     <button class='btn btn--secondary'>Start Application</button>
#                                 </a>
#                             </div>
#                         </div>
#                     </div>
#
#                 <div class="footer-bottom-container bg-color-primary-dark mob-bigger-panel">
#                     <div class="panel-footer panel-footer--flex">
#                         <div class="footer-bottom-left">
#                             <p class='sub-heading sub-heading--white landscape-hidden'>
#                                 Subscribe to our Newsletter
#                             </p>
#                             <p class='sub-heading sub-heading--white landscape-only'>Newsletter</p>
#                             <form
#                                 action="//spiced-academy.us12.list-manage.com/subscribe/post?u=d484949f27c464f21ce2d4182&amp;id=fe8732373f"
#                                 method='POST' target="_blank">
#                                 <div class="field">
#                                     <input id="footer-name" type="text" name="NAME" class='subscribe-input'
#                                         placeholder=Name autocomplete='off' required>
#                                     <label for="footer-name">Name</label>
#                                 </div>
#                                 <div class="field">
#                                     <input id="footer-email" type="email" name="EMAIL" class='subscribe-input'
#                                         placeholder=Email autocomplete='off' required>
#                                     <label for="footer-email">Email</label>
#                                 </div>
#                                 <p class='disclaimer'>
#                                     * By clicking Submit, I acknowledge that I have read and agree with the Spiced Academy Privacy Policy.
#                                 </p>
#                                 <button class='btn btn--secondary'>SUBMIT</button>
#                             </form>
#                             <p class='copyright'>&copy; 2020 Spiced Academy</p>
#                         </div>
#                     </div>
#
#                     <div class="panel-footer footer-bottom-right footer-bottom-right--flex">
#                         <div class="quick-links">
#                             <p class='footer-title'>Quick Links</p>
#                             <a class="link p-mid-size" href="/program">Programs</a>
#                             <a class="link p-mid-size" href="/about">About</a>
#                             <a class="link p-mid-size" href="/careers">Careers</a>
#                         </div>
#
#                         <div class="social">
#                             <p class='footer-title'>Social</p>
#                             <div class="footer-icons">
#                                 <a href="https://www.instagram.com/spicedacademy/" rel="nofollow noopener" target="_blank">
#                                     <img src="/img/icons/instagram-icon.png" alt="instagram">
#                                 </a>
#                                 <a href="https://www.facebook.com/spicedacademy/" rel="nofollow noopener" target="_blank">
#                                     <img src="/img/icons/facebook-icon.png" alt="facebook">
#                                 </a>
#                             </div>
#                         </div>
#
#                         <div class="contact">
#                             <p class='footer-title'>Contact Info</p>
#                             <p class='mail-to p-mid-size'>
#                                 <a href="mailto:info@spiced-academy.com">info@spiced-academy.com</a>
#                             </p>
#                             <p>+49 30 5093 1680</p>
#                         </div>
#
#                         <div class="legal">
#                             <p class='footer-title'>Legal</p>
#                             <a class='disclaimer' href="/disclaimer">
#                                 <p class='p-mid-size'>Disclaimer</p>
#                             </a>
#                             <a class='privacy' href="/privacy">
#                                 <p class='p-mid-size'>Privacy</p>
#                             </a>
#                             <a class='imprint' href="/imprint">
#                                 <p class='p-mid-size'>Imprint</p>
#                             </a>
#                         </div>
#                     </div>
#                 </div>
#             </footer>
#         </section>        <div class='covid-warning-banner fade-out '>
#             <div>
#                 <p>See our <a href='/coronavirus'>up-to-date response to COVID-19</a>.</p>
#             </div>
#             <div>
#                 <p class='js-close-covid-warning'>X</p>
#             </div>
#         </div>        <div class="js-cookie-warning cookie-warning-container fade-out">
#             <div class="cookie-warning-text">
#                 <p>We use cookies 🍪 to enhance your experience on our site, and to serve you advertising that may interest you. If that's ok with you, simply close this message and keep browsing. Otherwise, <a href="/privacy">click here to find out more info.</a></p>
#             </div>
#
#             <p class='js-close-cookie-warning close-cookie-warning'>X</p>
#         </div>    </div>
#
#     <script src="/js/script.js" charset="utf-8"></script>
#     <script src="/js/cookie-warning.js" charset="utf-8"></script>
#     <script src="/js/covid-warning.js" charset="utf-8"></script>
# </body>
#
# </html>

# %% [markdown]
# ### Step 2. Convert the raw HTML string to a BeautifulSoup object, so that we can parse the data.

# %% [markdown]
# Did you notive with the definition of HTML that there is both Markup and Markdown apparently?
#
# Go for the shortest explanation at the moment: https://www.quora.com/What-is-the-difference-between-markup-and-markdown

# %%
from bs4 import BeautifulSoup
spiced_soup = BeautifulSoup(spiced_html, 'html.parser')
print(f"""{type(spiced_soup)} \n
{spiced_soup}""")
# Out:
# <class 'bs4.BeautifulSoup'>
#
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <head>
# <title>Your new career starts here | Spiced Academy</title>
# <meta content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science." name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <link href="https://fonts.googleapis.com/css?family=Poppins:300,400,600&amp;display=swap" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=IBM+Plex+Mono:400,500&amp;display=swap" rel="stylesheet"/>
# <link href="/css/main.css" rel="stylesheet"/>
# <link href="/apple-touch-icon.png?v=3" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png?v=3" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png?v=3" rel="icon" sizes="16x16" type="image/png"/>
# <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="DICJgJwgfNeeiq66MAwDzpaeqBBgDqZsBNFBMwVtoaY" name="google-site-verification"/>
# <meta content="#2E016D" name="theme-color">
# <meta content="noodp" name="robots"/>
# <link href="https://www.spiced-academy.com/en" rel="canonical"/>
# <link href="https://www.spiced-academy.com/en/" hreflang="en" rel="alternate">
# <link href="https://www.spiced-academy.com/de/" hreflang="de" rel="alternate">
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Spiced Academy | Your new career starts here" property="og:title"/>
# <meta content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science." property="og:description"/>
# <meta content="https://www.spiced-academy.com/" property="og:url"/>
# <meta content="Spiced Academy" property="og:site_name"/>
# <meta content="https://www.facebook.com/spicedacademy" property="article:publisher"/>
# <meta content="1214485688610932" property="fb:app_id"/>
# <meta content="https://www.spiced-academy.com/img/people/spiced_share.jpg" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science." name="twitter:description"/>
# <meta content="Your new career starts here | Spiced Academy – A Coding Academy in Berlin" name="twitter:title"/>
# <meta content="@SPICEDacademy" name="twitter:site"/>
# <meta content="https://www.spiced-academy.com/img/people/spiced_share.jpg" name="twitter:image"/>
# <meta content="@SPICEDacademy" name="twitter:creator"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-78282401-1"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag() { dataLayer.push(arguments); }
#       gtag('js', new Date());
#       gtag('config', 'UA-78282401-1');
#       gtag('config', 'AW-882057422');
#     </script>
# <!-- Facebook Pixel Code -->
# <script>
#       !function (f, b, e, v, n, t, s) {
#         if (f.fbq) return; n = f.fbq = function () {
#           n.callMethod ?
#             n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#         };
#         if (!f._fbq) f._fbq = n; n.push = n; n.loaded = !0; n.version = '2.0';
#         n.queue = []; t = b.createElement(e); t.async = !0;
#         t.src = v; s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s)
#       }(window, document, 'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '1628135084116192');
#       fbq('track', 'PageView');
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=1628135084116192&amp;ev=PageView
#     &amp;noscript=1" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# <!-- DO NOT MODIFY -->
# <script>
#       var i = new Image(); i.src = "https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=";
#     </script>
# <noscript>
# <img height="1" src="https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&amp;s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=
#     https://alb.reddit.com/snoo.gif?q=CAAHAAABAAoACQAAAAAETYmbAA==&amp;s=eUBwdmUHxwTWcJzXvTt1feUOEDHpTyhp333E0DdefAM=
#     " style="display:none" width="1"/>
# </noscript>
# <!-- End Reddit Conversion Pixel -->
# </link></link></meta></meta></head>
# <body>
# <header>
# <div class="header-left">
# <a href="/">
# <img alt="Spiced logo" class="header-logo" src="/img/Spiced_Logo_Dark.svg"/>
# </a>
# <div class="header-links">
# <ul class="top-level-menu">
# <li>
# <a href="/program">PROGRAMS</a>
# <ul class="dropdown">
# <li><a href="/program/full-stack-web-development">Web Development</a></li>
# <li><a href="/program/data-science">Data Science</a></li>
# <li><a href="/program/data-analytics">Data Analytics</a></li>
# </ul>
# </li>
# <li>
# <a href="#">LOCATIONS</a>
# <ul class="dropdown">
# <li><a href="/berlin">Berlin</a></li>
# <li><a href="/hamburg">Hamburg</a></li>
# <li><a href="/cologne">Cologne</a></li>
# <li><a href="/stuttgart">Stuttgart</a></li>
# </ul>
# </li>
# </ul>
# <a class="apply-now" href="/apply">
#                     APPLY NOW
#                 </a>
# </div>
# </div>
# <div class="header-right">
# <div class="header-links fade-header">
# </div>
# <p class="js-language-toggle language-toggle">
# <a href="/lng/de" style="font-weight:100;">DE</a> | <a href="/lng/en" style="font-weight:900;">EN</a>
# </p>
# <div id="nav-icon">
# <span></span>
# <span></span>
# </div>
# </div>
# <div class="header-sidebar-container">
# <div class="nav-links-container">
# <div>
# <h4 class="lighter">
# <a href="/program">Programs</a>
# <span class="toggler-open"></span>
# </h4>
# <ul class="toggler-open">
# <li>
# <a href="/program/full-stack-web-development">Web Development</a>
# </li>
# <li>
# <a href="/program/data-science">Data Science</a>
# </li>
# <li>
# <a href="/program/data-analytics">Data Analytics</a>
# </li>
# </ul>
# </div>
# <div>
# <h4 class="lighter">
# <a href="#">Locations</a>
# <span></span>
# </h4>
# <ul>
# <li>
# <a href="/berlin">Berlin</a>
# </li>
# <li>
# <a href="/hamburg">Hamburg</a>
# </li>
# <li>
# <a href="/cologne">Cologne</a>
# </li>
# <li>
# <a href="/stuttgart">Stuttgart</a>
# </li>
# </ul>
# </div>
# <ul>
# <li>
# <a href="/about">About</a>
# </li>
# <li>
# <a href="/financing">Financing</a>
# </li>
# </ul>
# <ul>
# <li>
# <a href="/graduates">Graduates</a>
# </li>
# <li>
# <a href="/outcomes">Outcomes</a>
# </li>
# <li>
# <a href="/hiring">Hire a Spicedling</a>
# </li>
# <li>
# <a href="/faq">FAQ</a>
# </li>
# <li>
# <a href="https://blog.spiced-academy.com/" target="_blank">Blog</a>
# </li>
# </ul>
# <div class="apply-nav-container">
# <a class="apply-now" href="/apply">
#                         APPLY NOW
#                     </a>
# </div>
# </div>
# </div>
# </header>
# <div class="scroll-container">
# <section class="js-header-left-dark js-header-right-light mob-col-reverse">
# <div class="panel v-center-h-end v-center-h-center--mob">
# <div class="text-container text-container--mob-center">
# <h1 class="main-heading main-heading--future">
#
#                     Your future in tech
#             </h1>
# <h3 class="sub-heading">Kickstart your new career with our intensive, on-site tech programs in Web Development and Data Science.</h3> <a href="/program">
# <button class="btn btn--primary">Start your journey</button>
# </a>
# </div>
# </div>
# <div class="panel bg-color-primary-light duel-background panel-center">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/people/coding_bootcamp_r_homepage_spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-action">
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-white"></div>
# </div> </div>
# </section>
# <section class="js-header-left-light js-header-right-light mob-bg-color-action-dark" id="start-journey">
# <div class="panel">
# <img alt="spiced student" class="single-panel-image student-built-image" src="/img/people/spiced-academy-homepage-2.jpg"/> </div>
# <div class="panel bg-color-action flex-center">
# <div class="triangle-top-right triangle-top-right--action"></div>
# <div class="text-container text-container--simple">
# <h1 class="main-heading main-heading--space-bottom main-heading--secondary main-heading--space-bottom">
#                 Your new career starts here
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="">
#                                 Get all the tools you need to enter today’s tech job market
#                             </h4>
# <p class="">Whether you’re looking to level up or switch fields entirely, Spiced gives you the skills to get hired. Build a portfolio full of real-life projects using the most in-demand technologies on the market - ready to impress any hiring manager.</p>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="js-header-left-light js-header-right-dark">
# <div class="panel bg-color-primary-light v-center-h-center v-center-h-center--color-white v-center-h-center--mob-left">
# <div class="triangle-top-left-action city"></div>
# <div class="text-container text-container--simple city">
# <h1 class="main-heading">
#
#                         Our Programs
#                 </h1>
# <h3 class="sub-heading">Join 900+ Spicedlings and take the leap into tech</h3> </div>
# </div>
# <div class="panel bg-color-white v-center-h-center city">
# <div class="city-cohort-dates">
# <div>
# <details>
# <summary>
#                             Web Development
#                         </summary>
# <p>Get all the skills you need to kickstart your career in Web Development.</p>
# <p class="bold next-cohort">Courses in Berlin, Cologne, Hamburg, Stuttgart</p>
# <a href="/program/full-stack-web-development">
# <button class="btn btn--thin btn--secondary">Read more</button>
# </a>
# </details>
# </div>
# <div>
# <details>
# <summary>
#                             Data Science
#                         </summary>
# <p>Unlock the power of data with our immersive Data Science bootcamps.</p>
# <p class="bold next-cohort">Courses in Berlin, Cologne, Hamburg, Stuttgart</p>
# <a href="/program/data-science">
# <button class="btn btn--thin btn--secondary">Read more</button>
# </a>
# </details>
# </div>
# <div>
# <details>
# <summary>
#                             Data Analytics
#                         </summary>
# <p>Get a jump-start into the world of data processing with our 9-week Data Analytics bootcamp.</p>
# <p class="bold next-cohort">Courses in Berlin</p>
# <a href="/program/data-analytics">
# <button class="btn btn--thin btn--secondary">Read more</button>
# </a>
# </details>
# </div>
# </div>
# </div>
# </section>
# <section class="js-header-left-light js-header-right-light">
# <div class="panel mob-one-third-panel mob-bg-color-primary-light">
# <div class="triple-image-container triple-image-container--two-images-mobile">
# <img alt="spiced-academy-homepage-3" src="/img/people/spiced-academy-homepage-3.jpg"/>
# <img alt="spiced-academy-homepage-7" class="small-image" src="/img/people/spiced-academy-homepage-7.jpg"/>
# <img alt="spiced-academy-homepage-6" class="small-image" src="/img/people/spiced-academy-homepage-8.jpg"/>
# </div> </div>
# <div class="panel bg-color-primary-dark panel-employment mob-two-thirds-panel">
# <div class="triangle-top-right triangle-top-right--primary"></div>
# <div class="start-application-container">
# <div class="employment-rate-container">
# <div class="employment-percentage">
# <div>
# <div class="main-text">4.7</div>
# <div class="sub-text">out of 5</div>
# </div>
# </div>
# <h3 class="sub-heading sub-heading--white">Average review on Course Report</h3>
# </div>
# <div class="award-container">
# <img alt="course report award full stack" src="/img/icons/best_coding_bootcamp_2019_white_v2.png"/>
# <img alt="course report award Data Science" src="/img/icons/best_data_science_bootcamp_2019_white_v2.png"/>
# </div>
# </div>
# </div></section>
# <section class="js-header-left-dark js-header-right-light mob-col-reverse">
# <div class="panel bg-color-white mob-two-thirds-panel">
# <div class="action-box action-box--right">
# <h1 class="main-heading main-heading--off-center-left main-heading--space-bottom">Career <br/> Services</h1>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">Practical, real-world approach</p>
# <p class="mob-only career-mob-heading">Real-world technical interviews</p>
# <p class="mob-hidden p-smaller">An extensive focus on passing real-world technical interviews.</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">Tailored coaching sessions</p>
# <p class="mob-only career-mob-heading">Tailored coaching sessions</p>
# <p class="mob-hidden p-smaller">Unlimited one-to-one coaching sessions, helping you to develop professionally.</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">More than just technical skills</p>
# <p class="mob-only career-mob-heading">Professional development</p>
# <p class="mob-hidden p-smaller">We're here to support you with the personal changes in your career transition, too.</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right-pink"></div>
# </div>
# <p class="bold mob-hidden">An insider view</p>
# <p class="mob-only career-mob-heading">An insider view</p>
# <p class="mob-hidden p-smaller">We share the insider view of the the latest recruitment processes in Germany and beyond.</p>
# </div> </div>
# <div class="panel">
# <img alt="career-services" class="single-panel-image student-built-image" src="/img/staff/career-services.jpg"/> </div>
# </section>
# <section class="js-header-left-light js-header-right-light">
# <div class="panel bg-color-white mob-hidden landscape-block">
# <div class="three-quarter-panel">
# <img alt="alumni-raul-spiced" class="single-panel-image student-built-image" src="/img/testimonials/main-testimonial-spiced.jpg"/> </div>
# <div class="">
# <div class="our-students-work-at">
# <h4>Our students now work at:</h4>
# <div class="four-logo-container">
# <div class="company-logo-container">
# <img alt="bcg" src="/img/company-logos/bcg-logo-grey.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="infarm" src="/img/company-logos/infarm-logo-grey.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="Ebay" src="/img/company-logos/ebay-logo-grey.svg"/>
# </div>
# <div class="company-logo-container">
# <img alt="audible" src="/img/company-logos/wework-logo-grey.svg"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="panel mob-full-panel">
# <div class="half-panel bg-color-action">
# <div class="quote-block">
# <p class="quotation-mark">"</p>
# <p class="quotation">I now have a job with great prospects, in a company which offers me a chance to learn and grow. Thanks to Spiced, my life has completely changed.</p>
# <p class="quotation-mark quotation-mark-bottom">"</p>
# <div class="student-name-job">
# <p class="student-name">Raul Iglesias</p>
# <p class="student-job">Web Developer at Push Creative Ventures</p>
# </div>
# </div> </div>
# <div class="half-panel bg-color-action-dark"></div>
# </div>
# </section>
# <section class="js-header-left-light js-header-right-dark full-height-section full-height-panels">
# <div class="panel mob-smaller-panel mob-top-header-padding">
# <div class="based-in-half-panel bg-color-primary-light panel-bottom">
# <h2 class="panel-text-overlap">Spiced is <br/>based in...</h2>
# </div>
# <div class="based-in-half-panel bg-color-primary-dark"></div>
# </div>
# <div class="panel">
# <div class="cities-container">
# <a class="city-container" href="/berlin">
# <div class="city-icon-container city-icon-container--dark">
# <img alt="Berlin icon" class="city-icon" src="/img/icons/berlin-icon.svg"/>
# </div>
# <p>Berlin</p>
# </a>
# <a class="city-container" href="/hamburg">
# <div class="city-icon-container city-icon-container--dark">
# <img alt="Hamburg icon" class="city-icon" src="/img/icons/hamburg-icon.svg"/>
# </div>
# <p>Hamburg</p>
# </a>
# <a class="city-container" href="/cologne">
# <div class="city-icon-container city-icon-container--light">
# <img alt="Cologne icon" class="city-icon" src="/img/icons/cologne-icon.svg"/>
# </div>
# <p>Cologne</p>
# </a>
# <a class="city-container stuttgart" href="/stuttgart">
# <div class="city-icon-container city-icon-container--light">
# <img alt="stuttgart icon" class="city-icon" src="/img/icons/stuttgart-icon.svg"/>
# </div>
# <p>Stuttgart</p>
# </a>
# </div>
# </div>
# </section>
# <section class="js-header-left-dark js-header-right-dark graduate-testimonials">
# <div class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-0 js-carousel-slide-0 js-carousel-slide-0 fade-in">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-parinaz-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next js-btn">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center js-carousel-slide-0 fade-in">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                                 Parinaz Roghany<br/>Full Stack Web Developer at Ebay
#                             </h4>
# <p class="text-container-height">I wanted to learn JavaScript and Spiced’s Full Stack program sounded great. It was so cool learning all these things like real-time chatting and building your own online social media platform.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-1 js-carousel-slide-1 js-carousel-slide-1 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-kent-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next js-btn">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center js-carousel-slide-1 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                                 Kent Troutman<br/>Data Scientist at Deutsche Bundesbank
#                             </h4>
# <p class="text-container-height">The intense method of the boot camp helped me get to the next level skill-wise. I kept up my end and worked hard, as did my classmates, and Kristian made sure that no one was left behind.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-2 js-carousel-slide-2 js-carousel-slide-2 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-olof-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next js-btn">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center js-carousel-slide-2 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                                 Olof Reimegård<br/>Full Stack Web Developer at Zaplox
#                             </h4>
# <p class="text-container-height">I made the decision to do the course and since the first day I haven't looked back. The curriculum feels tailored for the job and is constantly updated to match the fast changing job market. If you feel willing and ready to really dive into coding then this course is for you.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-3 js-carousel-slide-3 js-carousel-slide-3 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-lilian-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next js-btn">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center js-carousel-slide-3 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <h4 class="sub-heading sub-heading--primary-light">
#                                 Lilian van Someren Greve<br/>Junior Data Scientist at TeamViewer
#                             </h4>
# <p class="text-container-height">Having worked in Business Intelligence, Spiced was able to bridge the gaps in my knowledge regarding Python and a deeper understanding of how some key Data Science models work. You can learn an amazing amount in 3 months, if you're willing to.</p>
# </div>
# </div>
# </div>
# </div> <div class="panel min-height-panel bg-color-white mob-top-panel mob-center js-carousel-slide-4 js-carousel-slide-4 js-carousel-slide-4 fade-out">
# <div class="circle-image-container">
# <div class="circle-half circle-half--left" style="background-image: url(/img/testimonials/alumni-alex-spiced.jpg); ">
# </div>
# <div class="top-right-circle circle-quarter bg-color-pink">
# <div class="next-link-container">
# <p class="link js-next js-btn">Next</p>
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# <div class="shape-box-small--chevron shape-box-small--chevron--white js-btn js-btn"></div>
# </div>
# </div>
# </div>
# <div class="bottom-right-circle circle-quarter bg-color-action"></div>
# </div></div>
# <div class="panel flex-center js-carousel-slide-4 fade-out">
# <div class=""></div>
# <div class="text-container text-container--simple text-container--center-short-txt">
# <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                 What our students say:
#
#             </h1>
# <div class="career-start-container--subheading-container">
# <div class="shape-box-small small-shape-spacer-container">
# <div class="shape-box-small--triangle-top-right"></div>
# </div>
# <div>
# <a class="sub-heading external-link" href="https://www.seoberlino.com/en" rel="noopener noreferrer" target="_blank">
#                                 Alex Bieth<br/>Freelance Consultant at SEO Berlino
#                             </a>
# <p class="text-container-height">Challenging and extremely rewarding - Spiced gave me the skills needed to become a Full Stack Web Developer. I have been coding every day since I finished the course!</p>
# </div>
# </div>
# </div>
# </div> <script src="/js/carousel.js"></script>
# <script src="/js/details-summary.js"></script>
# </section>
# <section class="mob-bg-color-primary-dark" id="contact-us">
# <footer>
# <div class="footer-top-container mob-smaller-panel mob-top-panel">
# <div class="panel-footer panel-footer--flex">
# <div class="footer-top-panel">
# <div class="mob-hidden">
# <h2>Questions?</h2>
# <p class="sub-heading sub-heading--grey">You can head to our <a href="/faq">FAQ</a> page or...</p>
# </div>
# <a href="https://calendly.com/spicedacademy/15min?month=2020-02" rel="nofollow noopener" target="_blank">
# <button class="btn btn--primary">Schedule a Chat</button>
# </a>
# </div>
# </div>
# <div class="panel-footer panel-footer--flex bg-color-primary-light">
# <div class="footer-top-panel footer-top-panel--white">
# <div class="mob-hidden">
# <h2 class="lighter">Ready?</h2>
# <p class="sub-heading">Take the leap and begin your application online.</p>
# </div>
# <a href="/apply">
# <button class="btn btn--secondary">Start Application</button>
# </a>
# </div>
# </div>
# </div>
# <div class="footer-bottom-container bg-color-primary-dark mob-bigger-panel">
# <div class="panel-footer panel-footer--flex">
# <div class="footer-bottom-left">
# <p class="sub-heading sub-heading--white landscape-hidden">
#                                 Subscribe to our Newsletter
#                             </p>
# <p class="sub-heading sub-heading--white landscape-only">Newsletter</p>
# <form action="//spiced-academy.us12.list-manage.com/subscribe/post?u=d484949f27c464f21ce2d4182&amp;id=fe8732373f" method="POST" target="_blank">
# <div class="field">
# <input autocomplete="off" class="subscribe-input" id="footer-name" name="NAME" placeholder="Name" required="" type="text"/>
# <label for="footer-name">Name</label>
# </div>
# <div class="field">
# <input autocomplete="off" class="subscribe-input" id="footer-email" name="EMAIL" placeholder="Email" required="" type="email"/>
# <label for="footer-email">Email</label>
# </div>
# <p class="disclaimer">
#                                     * By clicking Submit, I acknowledge that I have read and agree with the Spiced Academy Privacy Policy.
#                                 </p>
# <button class="btn btn--secondary">SUBMIT</button>
# </form>
# <p class="copyright">© 2020 Spiced Academy</p>
# </div>
# </div>
# <div class="panel-footer footer-bottom-right footer-bottom-right--flex">
# <div class="quick-links">
# <p class="footer-title">Quick Links</p>
# <a class="link p-mid-size" href="/program">Programs</a>
# <a class="link p-mid-size" href="/about">About</a>
# <a class="link p-mid-size" href="/careers">Careers</a>
# </div>
# <div class="social">
# <p class="footer-title">Social</p>
# <div class="footer-icons">
# <a href="https://www.instagram.com/spicedacademy/" rel="nofollow noopener" target="_blank">
# <img alt="instagram" src="/img/icons/instagram-icon.png"/>
# </a>
# <a href="https://www.facebook.com/spicedacademy/" rel="nofollow noopener" target="_blank">
# <img alt="facebook" src="/img/icons/facebook-icon.png"/>
# </a>
# </div>
# </div>
# <div class="contact">
# <p class="footer-title">Contact Info</p>
# <p class="mail-to p-mid-size">
# <a href="mailto:info@spiced-academy.com">info@spiced-academy.com</a>
# </p>
# <p>+49 30 5093 1680</p>
# </div>
# <div class="legal">
# <p class="footer-title">Legal</p>
# <a class="disclaimer" href="/disclaimer">
# <p class="p-mid-size">Disclaimer</p>
# </a>
# <a class="privacy" href="/privacy">
# <p class="p-mid-size">Privacy</p>
# </a>
# <a class="imprint" href="/imprint">
# <p class="p-mid-size">Imprint</p>
# </a>
# </div>
# </div>
# </div>
# </footer>
# </section> <div class="covid-warning-banner fade-out">
# <div>
# <p>See our <a href="/coronavirus">up-to-date response to COVID-19</a>.</p>
# </div>
# <div>
# <p class="js-close-covid-warning">X</p>
# </div>
# </div> <div class="js-cookie-warning cookie-warning-container fade-out">
# <div class="cookie-warning-text">
# <p>We use cookies 🍪 to enhance your experience on our site, and to serve you advertising that may interest you. If that's ok with you, simply close this message and keep browsing. Otherwise, <a href="/privacy">click here to find out more info.</a></p>
# </div>
# <p class="js-close-cookie-warning close-cookie-warning">X</p>
# </div> </div>
# <script charset="utf-8" src="/js/script.js"></script>
# <script charset="utf-8" src="/js/cookie-warning.js"></script>
# <script charset="utf-8" src="/js/covid-warning.js"></script>
# </body>
# </html>

# %% [markdown]
# div element: https://www.w3schools.com/html/html_classes.asp

# %%
spiced_soup.find_all('div', 
                     attrs = {'class' : 'city-cohort-dates',
                             }
                    )[0].find_all('p')[2]
# Out:
# <p>Unlock the power of data with our immersive Data Science bootcamps.</p>

# %% [markdown]
# ### Step 3. Use the BeautifulSoup object to parse the HTML document tree down to the tag that contains the data you want.
# - There are multiple ways to get to the solution!
# - .find() always returns the first instance of your "query"
# - .find_all() returns a list-like object (called a "ResultSet") that contains at least one matching result.
# - .text returns the actual part of the tag that is outside of the **< angled brackets  >** (i.e. the text)

# %% [markdown]
# #### Let's check the h1 level headers instead

# %%
spiced_soup.find_all('h1', attrs = {'class' : 'main-heading'}
                   )
# Out:
# [<h1 class="main-heading main-heading--future">
#
#                      Your future in tech
#              </h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--secondary main-heading--space-bottom">
#                  Your new career starts here
#
#              </h1>,
#  <h1 class="main-heading">
#
#                          Our Programs
#                  </h1>,
#  <h1 class="main-heading main-heading--off-center-left main-heading--space-bottom">Career <br/> Services</h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                  What our students say:
#
#              </h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                  What our students say:
#
#              </h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                  What our students say:
#
#              </h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                  What our students say:
#
#              </h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--primary">
#                  What our students say:
#
#              </h1>]

# %% [markdown]
# **Which index has the career services?**

# %%
spiced_soup.find_all('h1')[:4]
# Out:
# [<h1 class="main-heading main-heading--future">
#
#                      Your future in tech
#              </h1>,
#  <h1 class="main-heading main-heading--space-bottom main-heading--secondary main-heading--space-bottom">
#                  Your new career starts here
#
#              </h1>,
#  <h1 class="main-heading">
#
#                          Our Programs
#                  </h1>,
#  <h1 class="main-heading main-heading--off-center-left main-heading--space-bottom">Career <br/> Services</h1>]

# %% [markdown]
# **It looks like it's the fourth header.**

# %% [markdown]
# Access the text of a single element with .text.

# %%
spiced_soup.find_all('h1')[3]#.text
# Out:
# <h1 class="main-heading main-heading--off-center-left main-heading--space-bottom">Career <br/> Services</h1>

# %% [markdown]
# **Go to the end of Step 2 above, extract the text without the HTML tags.**

# %% [markdown]
# ### EXERCISE
#
# Check the error you get with the command:
#
# ``spiced_soup.find_all('h1')[:3].text``
#
# Write the command for finding the text in all of the h1 headers
# (use a for loop).

# %%
header_list= []
for element in spiced_soup.find_all('h1'):
    header = element.text.replace('\n', '')
    print(element.text)
    header_list.append(header)
# Out:
#
#                     Your future in tech
#
#
#                 Your new career starts here
#
#
#
#
#                         Our Programs
#
# Career  Services
#
#                 What our students say:
#
#
#
#                 What our students say:
#
#
#
#                 What our students say:
#
#
#
#                 What our students say:
#
#
#
#                 What our students say:

# %%
header_list
# Out:
# ['                                Your future in tech            ',
#  '                Your new career starts here                        ',
#  '                                        Our Programs                ',
#  'Career  Services',
#  '                What our students say:                        ',
#  '                What our students say:                        ',
#  '                What our students say:                        ',
#  '                What our students say:                        ',
#  '                What our students say:                        ']
